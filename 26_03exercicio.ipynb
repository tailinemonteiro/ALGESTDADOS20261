# %% [markdown]
# <a href="https://colab.research.google.com/github/tailinemonteiro/ALGESTDADOS20261/blob/main/26_03exercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nota= float(input("digite a nota:"))

if  nota >= 9:
  print("A - excelente")
elif nota >=7:
  print("B - aprovado")
elif nota>=5:
  print("C - recuperação")
else:
  print("D - reprovado")
# Out:
# digite a nota:8
# B - aprovado

# %%
numero= int(input("digite um numero de 1 a 7: "))

if numero == 1:
   print("segunda-feira")
elif numero == 2:
   print("terça-feira")
elif numero == 3:
   print("quarta-feira")
elif numero == 4:
   print("quinta-feira")
elif numero == 5:
   print("sexta-feira")
elif numero == 6
   print("sabado")
elif numero == 7
   print("domingo")
else:
  print("numero invalido")

# %%
nota = float(input("digite a nota: "))

if 0 <= 10:
  print(f"nota registrada: {nota}")
else:
  print("nota invalida")

# %%
idade = int(input("digite a idade: "))

if idade < 0:
   print("idade invalida")
elif idade < 12:
   print("criança")
elif idade <17:
   print("adolescente")
elif idade <59:
   print("adulto")
else:
  print("idoso")
# Out:
# digite a idade: 18
# adulto

# %%
print("menu: ")
print("1- agua R$2 ")
print("2- suco R$6 ")
print("3- cafe R$4 ")
item= int(input("escolha um item: "))

if not (1 <= item <= 3):
   print("opção invalida")
elif item == 1:
    print("agua - R$2")
elif item == 2:
    print("suco - R$6")
else:
    print("cafe - R$4")
# Out:
# menu:
# 1- agua R$2
# 2- suco R$6
# 3- cafe R$4
# escolha um item: 3
# cafe - R$4

# %%
a = float(input("lado A: "))
b = float(input("lado B: "))
c = float(input("lado C: "))

if a <= 0 or b <= 0 or c <= 0:
   print("valores invalidos")
elif a < b + c and b < a + c and c < a + b:
   print("forma um triangulo")
else:
   print("nao forma um triangulo")

# %%
valor = float(input("valor da compra: "))

if valor <= 0:
   print("valor invalido")
elif valor >= 500:
    desconto = 0.15
elif valor >= 200:
    desconto = 0.10
elif valor >= 100:
    desconto = 0.05
else:
    desconto = 0

valor_final = valor*(1-desconto)
print(f"desconto: {desconto*100}% ")
print(f"valor final: R${valor_final:.2f}")
# Out:
# valor da compra: 200
# desconto: 10.0%
# valor final: R$180.00

# %%
mes = int(input("digite o mes (1 a 12): "))

if mes < 1 or mes >12:
   print("mes ivalido")
elif mes == 12 or mes ==1 or mes == 2:
   print("verão")
elif mes == 3 or mes ==4 or mes == 5:
   print("outono")
elif mes == 6 or mes ==7 or mes == 8:
   print("inverno")
else:
   print("primavera")
# Out:
# digite o mes (1 a 12): 2
# verão
