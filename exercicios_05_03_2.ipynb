# %% [markdown]
# <a href="https://colab.research.google.com/github/tailinemonteiro/ALGESTDADOS20261/blob/main/exercicios_05_03_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= int(input("digite sua idade:"))
print(x+5)
# Out:
# digite sua idade:8
# 13

# %%
x= float(input("digite sua altura em metros:"))
print(x*2)
# Out:
# digite sua altura em metros:165
# 330.0

# %%
x=100
txt=str(x)
print(txt + " pontos alcançados")
# Out:
# 100 pontos alcançados

# %%
valor= int(input("digite 1 pra verdadeiro ou 0 pra falso:"))
resul= bool(valor)
print(resul)

# %%
x= int(input("digite o primeiro numero:"))
y= int(input("digite o segundo numero:"))
z= int(input("digite o terceiro numero:"))
print("o maior numero entre eles e:")
print(max(x, y, z))
# Out:
# digite o primeiro numero:8
# digite o segundo numero:9
# digite o terceiro numero:6
# o maior numero entre eles e:
# 9

# %%
a= float(input("digite o primeiro numero:"))
b= float(input("digite o segundo numero:"))
c= float(input("digite o terceiro numero:"))
d= float(input("digite o quarto numero:"))
print(f"a media dos numeros e: {((a+b+c+d) /4):.2f}")
# Out:
# digite o primeiro numero:5
# digite o segundo numero:5
# digite o terceiro numero:5
# digite o quarto numero:5
# a media dos numeros e: 5.00

# %%
x= int(input("digite sua idade:"))
print("a sua idade em meses e:" ,(x*12))
# Out:
# digite sua idade:18
# a sua idade em meses e: 216

# %%
x= str(input("digite um numero:"))
print("o numero tem:", len(x), "caracteres")
# Out:
# digite um numero:184
# o numero tem: 3 caracteres

# %%
x= int(input("digite um numero:"))
print("esse numero mais 1 e:", (x+1))
# Out:
# digite um numero:5
# esse numero mais 1 e: 6

# %%
num= input("digite um numero decimal:")
num_int= int(num)
num_bool= bool(num_int)
print("valor em float:", num_int)
print("valor em inteiro:" ,num_int)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_186/1546627301.py in <cell line: 0>()
# ----> 1 num= input("digite um numero decimal:")
#       2 num_int= int(num)
#       3 num_bool= bool(num_int)
#       4 print("valor em float:", num_int)
#       5 print("valor em inteiro:" ,num_int)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
num= input("digite um numero:")
num_int= int(num)
num_bool= bool(num_int)
print("inteiro:", num_int)
print("booleano:", {num_bool}, "pois apenas valores 0 ou vazio sao false em phyton")

# %%
kel= float(input("digite a temperatura em kelvin:"))
cel= kel- 273.15
print(f"a temperatura em graus celsius e {cel:.2f}")
# Out:
# digite a temperatura em kelvin:80
# a temperatura em graus celsius e -193.15

# %%
nome= input("digite seu nome completo:")
idade= int(input("digite sua idade:"))
salario= float(input("digite seeu salario:"))
print(f"seu nome e {nome}, sua idade e {idade} e seu salario e {salario:.3f}")
# Out:
# digite seu nome completo:tai
# digite sua idade:18
# digite seeu salario:1800
# seu nome e tai, sua idade e 18 e seu salario e 1800.000

# %%
preco= float(input("digite o preço do produto:"))
desconto= float(input("digite o desconto em porcentagem:"))
precofinal= prco-(preco*(desconto/100))
print(f"o preço final do produto e {precofinal:.2f}")

# %%
try:
  num= input("digite um valor numerico:")
  convertido= int(num)
  print(convertido)

except:
  print("valor invalido ")
# Out:
# digite um valor numerico:80
# 80
