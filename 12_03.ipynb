# %% [markdown]
# <a href="https://colab.research.google.com/github/tailinemonteiro/ALGESTDADOS20261/blob/main/12_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=3
print(a+b)
# Out:
# 13

# %%
a=10
b=3
print(a-b)
# Out:
# 7

# %%
a=10
b=3
print(a*b)
# Out:
# 30

# %%
a=10
b=3
print("a divisao real e:" ,{a/b})
# Out:
# a divisao real e: {3.3333333333333335}

# %%
a=10
b=3
print("a divisao inteira e:" ,{a//b})
# Out:
# a divisao inteira e: {3}

# %%
a=10
b=3
print(a%b)
# Out:
# 1

# %%
a=10
b=3
print(a**b)
# Out:
# 1000

# %%
nota= float(input("digite sua nota:"))
print(nota>= 6.0)
print(nota==10.0)
print(nota!=5.0)
print(nota<5.0)
# Out:
# digite sua nota:8
# True
# False
# True
# False

# %%
idade= float(input("digite sua idade:"))
renda= float(input("digite sua renda:"))
print(idade >= 18 and renda >= 1200)
print(idade >= 18 or renda >= 1200)
tem_debito= False
print(not tem_debito)
# Out:
# digite sua idade:18
# digite sua renda:1200
# True
# True
# True

# %%
print(2+3*4)
print((2+3)*4)
print(2**3**2)
print(10/2+3)
print(10/(2+3))
x= 3+2*4> 10 and not False
print(x)
# Out:
# 14
# 20
# 512
# 8.0
# 2.0
# True

# %%
a=15
b=4
print(a+b)
print(a-b)
print(a*b)
print("a divisao real e:" ,{a/b})
print("a divisao inteira e:" ,{a//b})
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# a divisao real e: {3.75}
# a divisao inteira e: {3}
# 3
# 50625

# %%
alunos= int(input("digite a quantidade de alunos:"))
grup= int(input("digite a quantidade de alunos por grupos:"))
print(f" a quantidade de grupos completos e:") , (alunos//grup)
print(f"a quantidade de alunos que sobraram e:" , (alunos%grup))

# %%
base= float(input("digite a base do retangulo:"))
altura= float(input("digite a altura do retangulo:"))
print(f" a area do retangulo e: {base * altura:.2f}")
# Out:
# digite a base do retangulo:8.5
# digite a altura do retangulo:3.2
#  a area do retangulo e: 27.20

# %%
segundos = 9875
horas= segundos//3600
resto= segundos% 3600
minutos= resto//60
seg= resto% 60
print(f"{horas}h:{minutos}min:{seg}seg")
# Out:
# 2h:44min:35seg

# %%
resul= 2**10
print(resul)
print("** significa potenciaçao em phyton")
raiz= 144**0.5
print(f"a raiz quadrada de 144 e:" , (raiz))
# Out:
# 1024
# ** significa potenciaçao em phyton
# a raiz quadrada de 144 e: 12.0
