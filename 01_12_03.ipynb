# %% [markdown]
# <a href="https://colab.research.google.com/github/tailinemonteiro/ALGESTDADOS20261/blob/main/01_12_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=3
print(a+b)
# Out:
# 13

# %%
a=10
b=3
print(a-b)
# Out:
# 7

# %%
a=10
b=3
print(a*b)
# Out:
# 30

# %%
a=10
b=3
print("a divisao real e:" ,{a/b})
# Out:
# a divisao real e: {3.3333333333333335}

# %%
a=10
b=3
print("a divisao inteira e:" ,{a//b})
# Out:
# a divisao inteira e: {3}

# %%
a=10
b=3
print(a%b)
# Out:
# 1

# %%
a=10
b=3
print(a**b)
# Out:
# 1000

# %%
nota= float(input("digite sua nota:"))
print(nota>= 6.0)
print(nota==10.0)
print(nota!=5.0)
print(nota<5.0)
# Out:
# digite sua nota:8
# True
# False
# True
# False

# %%
idade= float(input("digite sua idade:"))
renda= float(input("digite sua renda:"))
print(idade >= 18 and renda >= 1200)
print(idade >= 18 or renda >= 1200)
tem_debito= False
print(not tem_debito)
# Out:
# digite sua idade:18
# digite sua renda:1200
# True
# True
# True

# %%
print(2+3*4)
print((2+3)*4)
print(2**3**2)
print(10/2+3)
print(10/(2+3))
x= 3+2*4> 10 and not False
print(x)
# Out:
# 14
# 20
# 512
# 8.0
# 2.0
# True

# %%
a=15
b=4
print(a+b)
print(a-b)
print(a*b)
print("a divisao real e:" ,{a/b})
print("a divisao inteira e:" ,{a//b})
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# a divisao real e: {3.75}
# a divisao inteira e: {3}
# 3
# 50625

# %%
alunos= int(input("digite a quantidade de alunos:"))
grup= int(input("digite a quantidade de alunos por grupos:"))
print(f" a quantidade de grupos completos e:" , (alunos//grup))
print(f"a quantidade de alunos que sobraram e:" , (alunos%grup))
# Out:
# digite a quantidade de alunos:35
# digite a quantidade de alunos por grupos:7
#  a quantidade de grupos completos e: 5
# a quantidade de alunos que sobraram e: 0

# %%
base= float(input("digite a base do retangulo:"))
altura= float(input("digite a altura do retangulo:"))
print(f" a area do retangulo e: {base * altura:.2f}")
# Out:
# digite a base do retangulo:8.5
# digite a altura do retangulo:3.2
#  a area do retangulo e: 27.20

# %%
segundos = 9875
horas= segundos//3600
resto= segundos% 3600
minutos= resto//60
seg= resto% 60
print(f"{horas}h, {minutos}min e {seg}seg")
# Out:
# 2h, 44min e 35seg

# %%
resul= 2**10
print(resul)
print("** significa potenciaçao em phyton")
raiz= 144**0.5
print(f"a raiz quadrada de 144 e:" , (raiz))
# Out:
# 1024
# ** significa potenciaçao em phyton
# a raiz quadrada de 144 e: 12.0

# %%
temperatura= 38.5
print(temperatura>37.5)
print(temperatura==36.5)
print(temperatura!=40.0)
# Out:
# True
# False
# True

# %%
x= 10
y= 10
print(x == y) #true
print(x != y) #false
print(x >= y) #true
print(x <= y + 1) #true
# Out:
# True
# False
# True
# True

# %%
nota= float(input("digite sua nota:"))
print(f"ele foi aprovado? {nota>= 7.0}")
print(f"ele esta de recuperação? {(nota<7)and(nota>=5)}")
print(f"ele foi reprovado? {nota<5}")
# Out:
# digite sua nota:8.5
# ele foi aprovado? True
# ele esta de recuperação? False
# ele foi reprovado? False

# %%
a=5
b= "5"
print( a == b)
#false pois a esta em texto e o b esta em string

# %%
preco= float(input("digite o preço do produto: "))
print(f"o preço esta dentro do orçamento?:", preco<=50)
# Out:
# digite o preço do produto: 49
# o preço esta dentro do orçamento?: True

# %%
idade= int(input("digite sua idade: "))
print("voce pode votar?", idade >= 16)

# %%
renda= 2500
score= 720
print("emprestimo aprovado?", renda >= 2000 and score >= 700)

# %%
acesso=(int(input("digite seu nivel:")))
admin= bool(input("voce e administrador?:"))
print("acesso liberado?", admin==True or acesso >= 3)
# Out:
# digite seu nivel:4
# voce e administrador?:False
# acesso liberado? True

# %%
chovendo= True
temperatura= 30
print(f"esta chovendo?", (not chovendo), "\nE temperatura e a maior que 25°?", (temperatura > 25))

# %%
print("True and True =", True and True)
print("True and False =", True and False)
print("False and True =", True and True)
print("False and False=", True and False)
# Out:
# True and True = True
# True and False = False
# False and True = True
# False and False= False

# %%
print(5+2*3)
print((5+2)*3)
print(2**3**2)
print(10-4/2+1)
# Out:
# 11
# 21
# 512
# 9.0

# %%
resultado = 3+2*4**2-1
#1° passo>4**2
#2° passo>15*2
#3° passo>3+32-1
print(resultado)
resultado2= 3+(2*(4**2)-1)
print(resultado2)

# %%
x=4+3*2>9 and not (5==5)
print(x)
#para a espressão AND ser false, basta que uma das posiçoes seja false
# Out:
# False

# %%
a= 10/(2+3)
print(a) #resultado= False
