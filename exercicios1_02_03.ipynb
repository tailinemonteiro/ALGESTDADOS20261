# %% [markdown]
# <a href="https://colab.research.google.com/github/tailinemonteiro/ALGESTDADOS20261/blob/main/exercicios1_02_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome="tailine monteiro cabral"
idade=18
print(f"meu nome e {nome} e tenho {idade}")
# Out:
# meu nome e tailine monteiro cabral e tenho 18

# %%
nome="tailine"
print(f"boas vindas {nome}")
# Out:
# boas vindas tailine

# %%
numA=int(input("digite o primeiro numero:"))
numB=int(input("digite o segundo numero:"))
print(f"{numA} + {numB} = {numA+numB}")
# Out:
# digite o primeiro numero:2
# digite o segundo numero:2
# 2 + 2 = 4

# %%
antecessor=-1
sucessor=+1
num=int(input("digite um numero"))
print(f"antecessor de {num} ={num-1}")
print(f"sucesddor de {num}={num+1}")
# Out:
# digite um numero7
# antecessor de 7 =6
# sucesddor de 7=8

# %%
numB=int(input("digite o ano de nascimento:"))
numA=2026
print(f"{numA} - {numB} = {numA-numB}")
# Out:
# digite o ano de nascimento:2007
# 2026 - 2007 = 19

# %%
numA=int(input("digite a primeira nota:"))
numB=int(input("digite a segunda nota:"))
print(f'a media da notas:{(numA+numB)/2}')
# Out:
# digite a primeira nota:8
# digite a segunda nota:3
# a media da notas:5.5

# %%
print("Conversor de Temperatura Celsius para Fahrenheit")
numA = float(input("Digite a temperatura em graus Celsius: "))
fahrenheit = numA * 1.8 + 32
print(f"A temperatura em Fahrenheit é: {fahrenheit}°F")
# Out:
# Conversor de Temperatura Celsius para Fahrenheit
# Digite a temperatura em graus Celsius: 25
# A temperatura em Fahrenheit é: 77.0°F

# %%
print("Área do retangulo")
numA=float(input("digite a largura(cm):"))
numB=float(input("digite a altura(cm):"))
print(f"A área do retangulo é: {numA * numB} cm")
# Out:
# Área do retangulo
# digite a largura(cm):8.8
# digite a altura(cm):6
# A área do retangulo é: 52.800000000000004 cm

# %%
numA=int(input("digite um numero:"))
print(f"o quadrado do numero e: {numA*numA}")
# Out:
# digite um numero:8
# o quadrado do numero e: 64

# %%
num1 = input("Digite o primeiro número: ")
num2 = input("Digite o segundo número: ")
operador = input('Digite o operador (+, -, * ou /): ')
resultado = eval(num1+operador+num2)
print(resultado)
